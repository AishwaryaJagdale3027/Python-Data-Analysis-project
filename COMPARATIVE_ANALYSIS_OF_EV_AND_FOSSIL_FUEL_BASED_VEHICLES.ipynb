# %% [markdown]
# **COMPARATIVE ANALYSIS OF EV AND FOSSIL FUEL-BASED VEHICLES**

# %% [markdown]
# Objective:
# This analysis seeks to evaluate the perception and performance of Electric Vehicles (EVs) versus Fossil Fuel-based Vehicles among young respondents aged 18–25. Key factors include performance, cost efficiency, mileage, and
# future popularity trends.

# %%
import pandas as pd

# Load the uploaded CSV file to examine its structure and contents.
file_path = "/content/Research project updated for anudip (Aishwarya J)updated file - Form responses 1.csv"
data = pd.read_csv(file_path)

# %%
# Display the first few rows and the structure of the dataset to understand its content.
data.head()
# Out:
#            Timestamp            Name  Gender       Age  \
# 0  9/3/2024 14:52:19  Snehal phalke   Female  18 to 25
# 1  9/3/2024 14:55:07     Kavi Chavan  Female  25 to 35
# 2  9/3/2024 14:56:20  Shruti Shirke   Female  18 to 25
# 3  9/3/2024 15:00:14  Sakshi Bhosale  Female  18 to 25
# 4  9/3/2024 15:17:51         Vishal     Male  25 to 35
#
#   1.What type of vehicle do you primarily use?  \
# 0      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 1      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 2      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 3      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 4      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
#
#   2.What is your level of expertise in automotive technology?  \
# 0                                           Beginner
# 1                                           Beginner
# 2                                             Expert
# 3                                           Beginner
# 4                                       Intermediate
#
# ...

# %%
 data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 17 columns):
#  #   Column                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                       --------------  -----
#  0   Timestamp                                                                                                                    103 non-null    object
#  1   Name                                                                                                                         103 non-null    object
#  2   Gender                                                                                                                       103 non-null    object
# ...

# %%
data.shape
# Out:
# (103, 17)

# %%
data.describe()
# Out:
#        3.How would you rate the overall performance of vehicle?(Electrical vehicle)  \
# count                                         103.000000
# mean                                            3.475728
# std                                             0.998476
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        4.How would you rate the overall performance of vehicle?(Petrol/Diesel/CNG)
# count                                         103.000000
# mean                                            3.776699
# std                                             1.137007
# min                                             1.000000
# 25%                                             3.000000
# ...

# %%
data.tail()
# Out:
#               Timestamp            Name  Gender       Age  \
# 98   9/17/2024 17:07:35   Nikita Mishra    Male  18 to 25
# 99   9/17/2024 17:07:35  Durgesh Thakur    Male  18 to 25
# 100  9/17/2024 17:07:35  Priyanka kadam  Female  18 to 25
# 101  9/17/2024 17:07:35     Yash Shelke    Male  18 to 25
# 102  9/17/2024 17:07:35    kunal kedare    Male  18 to 25
#
#     1.What type of vehicle do you primarily use?  \
# 98       Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 99       Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 100      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 101      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
# 102      Fossil Fuel Vehicle (Petrol/Diesel/CNG)
#
#     2.What is your level of expertise in automotive technology?  \
# 98                                        Intermediate
# 99                                            Beginner
# 100                                           Advanced
# 101                                       Intermediate
# ...

# %%
# Pie Chart: Gender Distribution
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(10, 6))  # Width=10, Height=6

data['Gender'].value_counts().plot.pie(
    autopct='%1.1f%%',
    colors=[ 'darkblue', 'lightgreen'],
    title='Gender Distribution'
)
plt.ylabel('')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # Width=10, Height=6

# Create the bar chart
sns.countplot(data=data, x='Age', palette="viridis")
plt.title("Age Distribution")
plt.xlabel("Age Groups")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-61-2f6237ae5e14>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Age', palette="viridis")

# %%
import matplotlib.pyplot as plt
# Set figure size
plt.figure(figsize=(10, 6))  # Width=10, Height=6
# Histogram: EV Performance Ratings
sns.histplot(data=data, x='3.How would you rate the overall performance of vehicle?(Electrical vehicle)', kde=True, bins=5, color="green")
plt.title("Distribution of Performance Ratings for EVs")
plt.xlabel("Performance Rating")
plt.ylabel("Frequency")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Define the custom colormap
custom_cmap = LinearSegmentedColormap.from_list("blue_green", ["darkblue", "lightgreen"])

# Create the heatmap
sns.heatmap(data[numerical_columns].corr(), annot=True, cmap=custom_cmap, fmt=".2f")
plt.title("Correlation Heatmap of Performance Ratings")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Custom colors
custom_colors = ["darkblue", "lightgreen", "lightblue"]
plt.figure(figsize=(12, 8))

# Stacked bar chart
vehicle_age_data = data.groupby(['Age', '1.What type of vehicle do you primarily use?']).size().unstack()
vehicle_age_data.plot(kind="bar", stacked=True, color=custom_colors)
plt.title("Age Groups vs Vehicle Type Usage")
plt.ylabel("Count")
plt.xlabel("Age Groups")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(10, 6))  # Width=10, Height=6
# Line Chart: Ratings for Electric Vehicles Over Time (requires a timestamp or sequential index)
data['index'] = range(len(data))  # Add an index for sequential visualization
sns.lineplot(data=data, x='index', y='3.How would you rate the overall performance of vehicle?(Electrical vehicle)', color='blue')
plt.title("Performance Ratings for EVs Over Entries")
plt.xlabel("Index")
plt.ylabel("EV Performance Rating")
plt.show()

# %%
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(10, 6))  # Width=10, Height=6
# Histogram: Performance Ratings for Fossil Fuel Vehicles
sns.histplot(data=data, x='4.How would you rate the overall performance of vehicle?(Petrol/Diesel/CNG)', kde=True, bins=5, color="darkblue")
plt.title("Distribution of Performance Ratings for Fossil Fuel Vehicles")
plt.xlabel("Performance Rating")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

# Check if the column exists and preprocess if necessary
if '12.Would you recommend your type of vehicle to others?' in data.columns:
    # Count the responses
    recommend_counts = data['12.Would you recommend your type of vehicle to others?'].value_counts()

    # Plot a line chart
    plt.figure(figsize=(10, 6))
    plt.plot(recommend_counts.index, recommend_counts.values, marker='o', linestyle='-', color='blue', label='Responses')
    plt.title('Would You Recommend Your Type of Vehicle to Others?', fontsize=16)
    plt.xlabel('Response', fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks

# %% [markdown]
# # Conclusion:
# EVs are highly favored for their environmental benefits and future potential, particularly by younger generations. However, fossil fuel vehicles still lead in mileage and long-distance travel efficiency. While EVs show promise,
